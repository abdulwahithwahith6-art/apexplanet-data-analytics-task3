# %% [markdown]
# # Task 2 - SQL & Data Extraction
#
# ApexPlanet Data Analytics Internship
#
# This notebook demonstrates:
# - Connecting to SQLite Database
# - Running SQL Queries
# - Reading SQL data using Pandas

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("supermarket.db")
print("Database Connected Successfully!")
# Out:
# Database Connected Successfully!

# %%
query = "SELECT * FROM sales LIMIT 5"
df = pd.read_sql_query(query, conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: sales
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 query = "SELECT * FROM sales LIMIT 5"
# ----> 2 df = pd.read_sql_query(query, conn)
#       3 df
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# []

# %%
import os

print("Current Folder:", os.getcwd())
print("Database Exists:", os.path.exists("supermarket.db"))
# Out:
# Current Folder: c:\Users\Abdul Wahith\Desktop\apexplanet-data-analytics\scripts
# Database Exists: True

# %%
import os

for root, dirs, files in os.walk("."):
    if "supermarket.db" in files:
        print(os.path.join(root, "supermarket.db"))
# Out:
# .\supermarket.db

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# c:\Users\Abdul Wahith\Desktop\apexplanet-data-analytics\scripts

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# []

# %%
conn.close()

import sqlite3

conn = sqlite3.connect("supermarket.db")

cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 conn.close()
#       2
#       3 import sqlite3
#       4
#
# NameError: name 'conn' is not defined

# %%
import sqlite3

conn = sqlite3.connect("../supermarket.db")

cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('sales',)]

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Abdul Wahith\Desktop\apexplanet-data-analytics\scripts

# %%
import pandas as pd

query = "SELECT * FROM sales LIMIT 5"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Invoice_ID        Date Branch        City Customer_Type  Gender  \
# 0        1001  2026-01-01      A  Coimbatore        Member    Male
# 1        1002  2026-01-02      B     Chennai        Normal  Female
# 2        1003  2026-01-03      C   Bangalore        Member    Male
# 3        1004  2026-01-04      A  Coimbatore        Normal  Female
# 4        1005  2026-01-05      B     Chennai        Member    Male
#
#              Product_Line  Unit_Price  Quantity  Tax_5%   Total      Payment  \
# 0  Electronic Accessories         250         2    25.0   525.0         Cash
# 1     Fashion Accessories         500         1    25.0   525.0      Ewallet
# 2      Food and Beverages         150         5    37.5   787.5  Credit Card
# 3       Health and Beauty         350         3    52.5  1102.5         Cash
# 4      Home and Lifestyle         700         2    70.0  1470.0      Ewallet
#
#    Rating
# 0     8.5
# 1     9.0
# 2     8.8
# 3     7.9
# 4     9.5

# %%
query = """
SELECT Branch, COUNT(*) AS Total_Sales
FROM sales
GROUP BY Branch;
"""

pd.read_sql_query(query, conn)
# Out:
#   Branch  Total_Sales
# 0      A            4
# 1      B            3
# 2      C            3

# %%
query = """
SELECT AVG(Total) AS Average_Sale
FROM sales;
"""

pd.read_sql_query(query, conn)
# Out:
#    Average_Sale
# 0        1050.0

# %%
conn.close()
print("Database Closed Successfully!")
# Out:
# Database Closed Successfully!
